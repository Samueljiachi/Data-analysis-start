# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#path = "C:\\Users\\user\\3D Objects\\PLAY_TIME"

# %%
hotel = pd.read_csv("hotel_bookings.csv")

# %%
hotel
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
#we study the file and look for outliers

# %%
hotel.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
#to drop unnamed columns from the file

# %%
hotel.drop(columns = ["column name"],inplace = True)

# %%
#to rename a column

# %%
hotel.rename({"adults": "num_adults","children":"num_children","babies":"num_babies"},axis=1,inplace=True)

# %%
hotel.head(10)
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
# 5  Resort Hotel            0         14               2015               July
# 6  Resort Hotel            0          0               2015               July
# 7  Resort Hotel            0          9               2015               July
# 8  Resort Hotel            1         85               2015               July
# 9  Resort Hotel            1         75               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# ...

# %%
#finding null values

# %%
hotel.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# num_adults                             0
# num_children                           4
# num_babies                             0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
#checking for unique value in agent

# %%
hotel["agent"].unique()
# Out:
# array([ nan, 304., 240., 303.,  15., 241.,   8., 250., 115.,   5., 175.,
#        134., 156., 243., 242.,   3., 105.,  40., 147., 306., 184.,  96.,
#          2., 127.,  95., 146.,   9., 177.,   6., 143., 244., 149., 167.,
#        300., 171., 305.,  67., 196., 152., 142., 261., 104.,  36.,  26.,
#         29., 258., 110.,  71., 181.,  88., 251., 275.,  69., 248., 208.,
#        256., 314., 126., 281., 273., 253., 185., 330., 334., 328., 326.,
#        321., 324., 313.,  38., 155.,  68., 335., 308., 332.,  94., 348.,
#        310., 339., 375.,  66., 327., 387., 298.,  91., 245., 385., 257.,
#        393., 168., 405., 249., 315.,  75., 128., 307.,  11., 436.,   1.,
#        201., 183., 223., 368., 336., 291., 464., 411., 481.,  10., 154.,
#        468., 410., 390., 440., 495., 492., 493., 434.,  57., 531., 420.,
#        483., 526., 472., 429.,  16., 446.,  34.,  78., 139., 252., 270.,
#         47., 114., 301., 193., 182., 135., 350., 195., 352., 355., 159.,
# ...

# %%
#replace nan value with -1 in column agent
hotel["agent"].fillna(-1)
# Out:
# 0          -1.0
# 1          -1.0
# 2          -1.0
# 3         304.0
# 4         240.0
#           ...
# 119385    394.0
# 119386      9.0
# 119387      9.0
# 119388     89.0
# 119389      9.0
# Name: agent, Length: 119390, dtype: float64

# %%
#checking nan rows of num_children column 
hotel[hotel["num_children"].isna()]
# Out:
#             hotel  is_canceled  lead_time  arrival_date_year  \
# 40600  City Hotel            1          2               2015
# 40667  City Hotel            1          1               2015
# 40679  City Hotel            1          1               2015
# 41160  City Hotel            1          8               2015
#
#       arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 40600             August                        32                          3
# 40667             August                        32                          5
# 40679             August                        32                          5
# 41160             August                        33                         13
#
#        stays_in_weekend_nights  stays_in_week_nights  num_adults  ...  \
# 40600                        1                     0           2  ...
# 40667                        0                     2           2  ...
# ...

# %%
#checking nan rows of country column 
hotel[hotel["country"].isna()][["hotel","is_canceled","country"]]
# Out:
#                hotel  is_canceled country
# 30      Resort Hotel            0     NaN
# 4127    Resort Hotel            1     NaN
# 7092    Resort Hotel            1     NaN
# 7860    Resort Hotel            1     NaN
# 8779    Resort Hotel            1     NaN
# ...              ...          ...     ...
# 65908     City Hotel            1     NaN
# 65909     City Hotel            1     NaN
# 65910     City Hotel            1     NaN
# 80830     City Hotel            0     NaN
# 101488    City Hotel            0     NaN
#
# [488 rows x 3 columns]

# %%
#replacing nan rows with unknown in country column
hotel.fillna({"country":"UNKNOWN"},inplace = True)

# %%
hotel[["hotel","is_canceled","country"]]
# Out:
#                hotel  is_canceled country
# 0       Resort Hotel            0     PRT
# 1       Resort Hotel            0     PRT
# 2       Resort Hotel            0     GBR
# 3       Resort Hotel            0     GBR
# 4       Resort Hotel            0     GBR
# ...              ...          ...     ...
# 119385    City Hotel            0     BEL
# 119386    City Hotel            0     FRA
# 119387    City Hotel            0     DEU
# 119388    City Hotel            0     GBR
# 119389    City Hotel            0     DEU
#
# [119390 rows x 3 columns]

# %%
#droping row with nan values in the children column
hotel.dropna(subset=["num_children"],inplace = True)

# %%
#dropping company column because 90% where nan
hotel.drop(columns=["company"], inplace = True)

# %%
hotel.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'num_adults', 'num_children', 'num_babies',
#        'meal', 'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
hotel.dtypes
# Out:
# hotel                              object
# is_canceled                         int64
# lead_time                           int64
# arrival_date_year                   int64
# arrival_date_month                 object
# arrival_date_week_number            int64
# arrival_date_day_of_month           int64
# stays_in_weekend_nights             int64
# stays_in_week_nights                int64
# num_adults                          int64
# num_children                      float64
# num_babies                          int64
# meal                               object
# country                            object
# market_segment                     object
# distribution_channel               object
# is_repeated_guest                   int64
# previous_cancellations              int64
# previous_bookings_not_canceled      int64
# reserved_room_type                 object
# assigned_room_type                 object
# booking_changes                     int64
# ...

# %%
#changing datatypes of columns
hotel = hotel.astype({"is_canceled":"boolean","is_repeated_guest":"boolean","num_children":"int","agent":"int"})

# %%
hotel.dtypes
# Out:
# hotel                              object
# is_canceled                       boolean
# lead_time                           int64
# arrival_date_year                   int64
# arrival_date_month                 object
# arrival_date_week_number            int64
# arrival_date_day_of_month           int64
# stays_in_weekend_nights             int64
# stays_in_week_nights                int64
# num_adults                          int64
# num_children                        int32
# num_babies                          int64
# meal                               object
# country                            object
# market_segment                     object
# distribution_channel               object
# is_repeated_guest                 boolean
# previous_cancellations              int64
# previous_bookings_not_canceled      int64
# reserved_room_type                 object
# assigned_room_type                 object
# booking_changes                     int64
# ...

# %%
#grouping columns --bin columns--  note pd.cut is used to reduce the number of unique values you have into groups
hotel["lead_time"].unique()
# Out:
# array([342, 737,   7,  13,  14,   0,   9,  85,  75,  23,  35,  68,  18,
#         37,  12,  72, 127,  78,  48,  60,  77,  99, 118,  95,  96,  69,
#         45,  40,  15,  36,  43,  70,  16, 107,  47, 113,  90,  50,  93,
#         76,   3,   1,  10,   5,  17,  51,  71,  63,  62, 101,   2,  81,
#        368, 364, 324,  79,  21, 109, 102,   4,  98,  92,  26,  73, 115,
#         86,  52,  29,  30,  33,  32,   8, 100,  44,  80,  97,  64,  39,
#         34,  27,  82,  94, 110, 111,  84,  66, 104,  28, 258, 112,  65,
#         67,  55,  88,  54, 292,  83, 105, 280, 394,  24, 103, 366, 249,
#         22,  91,  11, 108, 106,  31,  87,  41, 304, 117,  59,  53,  58,
#        116,  42, 321,  38,  56,  49, 317,   6,  57,  19,  25, 315, 123,
#         46,  89,  61, 312, 299, 130,  74, 298, 119,  20, 286, 136, 129,
#        124, 327, 131, 460, 140, 114, 139, 122, 137, 126, 120, 128, 135,
#        150, 143, 151, 132, 125, 157, 147, 138, 156, 164, 346, 159, 160,
# ...

# %%
#checking the max and min value for lead_time in other to know how to do the grouping
hotel["lead_time"].describe()
# Out:
# count    119386.000000
# mean        104.014801
# std         106.863286
# min           0.000000
# 25%          18.000000
# 50%          69.000000
# 75%         160.000000
# max         737.000000
# Name: lead_time, dtype: float64

# %%
#now after looking at the max and min of lead_time we decided to group by 100
BIN = [0,100,200,300,400,500,600,700,800]
#we create labels so it can assign the lead_time value based on bin it falls under
LABEL = ["0-100","101-200","201-300","301-400","401-500","501-600","601-700","701-800"]
#we create a new column to put in the binned column
hotel["lead_time_binned"] = pd.cut(hotel["lead_time"], bins=BIN,labels=LABEL)

# %%
hotel[["lead_time","lead_time_binned"]]
# Out:
#         lead_time lead_time_binned
# 0             342          301-400
# 1             737          701-800
# 2               7            0-100
# 3              13            0-100
# 4              14            0-100
# ...           ...              ...
# 119385         23            0-100
# 119386        102          101-200
# 119387         34            0-100
# 119388        109          101-200
# 119389        205          201-300
#
# [119386 rows x 2 columns]

# %%
#seperating columns
#1st we create two new columns
hotel["arrival_date_month"] = hotel["arrival_date"].str.split("-",expand=True)[0]
hotel["arrival_date_year"]= hotel["arrival_date"].str.split("-",expand=True)[1]

#we got an error because arrival_date was not in our file as the tutorial we are following
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'arrival_date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[45], line 3
#       1 #seperating columns
#       2 #1st we create two new columns
# ...

# %%
#moving a column to another position 
hotel.head(3)
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel        False        342               2015               July
# 1  Resort Hotel        False        737               2015               July
# 2  Resort Hotel        False          7               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  num_adults  ...  \
# 0                        0                     0           2  ...
# 1                        0                     0           2  ...
# 2                        0                     1           1  ...
#
#    deposit_type  agent days_in_waiting_list customer_type   adr  \
# 0    No Deposit     -1                    0     Transient   0.0
# ...

# %%
column_to_move = hotel.pop("arrival_date_year")
hotel.insert(6,"arrival_date_year",column_to_move)
hotel.head(3)
# Out:
#           hotel  is_canceled  lead_time arrival_date_month  \
# 0  Resort Hotel        False        342               July
# 1  Resort Hotel        False        737               July
# 2  Resort Hotel        False          7               July
#
#    arrival_date_week_number  arrival_date_day_of_month  arrival_date_year  \
# 0                        27                          1               2015
# 1                        27                          1               2015
# 2                        27                          1               2015
#
#    stays_in_weekend_nights  stays_in_week_nights  num_adults  ...  \
# 0                        0                     0           2  ...
# 1                        0                     0           2  ...
# 2                        0                     1           1  ...
#
#    deposit_type  agent days_in_waiting_list customer_type   adr  \
# 0    No Deposit     -1                    0     Transient   0.0
# ...

# %%
hotel["hotel"].unique()
# Out:
# array(['Rsr H', 'Ciy H'], dtype=object)

# %%
#string cleaning   noted \ means instince  \n instince of a new line
hotel["hotel"] = hotel["hotel"].replace(["Resort hotel","Ciy H"],["RESORT hotel","City hotel"])

# %%
hotel["hotel"].unique()
# Out:
# array(['RESORT hotel', 'City hotel'], dtype=object)

# %%
#remove duplicate 
hotel.duplicated(keep=False)
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4          True
#           ...
# 119385    False
# 119386    False
# 119387    False
# 119388    False
# 119389    False
# Length: 119386, dtype: bool

# %%
hotel.loc[hotel.duplicated(keep=False)]
# Out:
#                hotel  is_canceled  lead_time arrival_date_month  \
# 4       RESORT hotel        False         14               July
# 5       RESORT hotel        False         14               July
# 21      RESORT hotel        False         72               July
# 22      RESORT hotel        False         72               July
# 39      RESORT hotel        False         70               July
# ...              ...          ...        ...                ...
# 119352    City hotel        False         63             August
# 119353    City hotel        False         63             August
# 119354    City hotel        False         63             August
# 119372    City hotel        False        175             August
# 119373    City hotel        False        175             August
#
#         arrival_date_week_number  arrival_date_day_of_month  \
# 4                             27                          1
# 5                             27                          1
# ...

# %%
#droping duplicates
hotel.drop_duplicates(keep="first",inplace = True)

# %%
hotel.loc[hotel.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [hotel, is_canceled, lead_time, arrival_date_month, arrival_date_week_number, arrival_date_day_of_month, arrival_date_year, stays_in_weekend_nights, stays_in_week_nights, num_adults, num_children, num_babies, meal, country, market_segment, distribution_channel, is_repeated_guest, previous_cancellations, previous_bookings_not_canceled, reserved_room_type, assigned_room_type, booking_changes, deposit_type, agent, days_in_waiting_list, customer_type, adr, required_car_parking_spaces, total_of_special_requests, reservation_status, reservation_status_date, lead_time_binned]
# Index: []
#
# [0 rows x 32 columns]
