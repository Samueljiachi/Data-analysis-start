# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plb

# %%
trans_data = pd.read_csv("trans_data.csv")
purchase = pd.read_csv("purchase.csv")

# %%
trans_data.head(10)
# Out:
#     DATE  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  \
# 0  43390          1            1000       1         5
# 1  43599          1            1307     348        66
# 2  43605          1            1343     383        61
# 3  43329          2            2373     974        69
# 4  43330          2            2426    1038       108
# 5  43604          4            4074    2982        57
# 6  43601          4            4149    3333        16
# 7  43601          4            4196    3539        24
# 8  43332          5            5026    4525        42
# 9  43330          7            7150    6900        52
#
#                                   PROD_NAME  PROD_QTY  TOT_SALES
# 0    Natural Chip        Compny SeaSalt175g         2        6.0
# 1                  CCs Nacho Cheese    175g         3        6.3
# 2    Smiths Crinkle Cut  Chips Chicken 170g         2        2.9
# 3    Smiths Chip Thinly  S/Cream&Onion 175g         5       15.0
# ...

# %%
str(trans_data)
# Out:
# '         DATE  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  \\\n0       43390          1            1000       1         5   \n1       43599          1            1307     348        66   \n2       43605          1            1343     383        61   \n3       43329          2            2373     974        69   \n4       43330          2            2426    1038       108   \n...       ...        ...             ...     ...       ...   \n264831  43533        272          272319  270088        89   \n264832  43325        272          272358  270154        74   \n264833  43410        272          272379  270187        51   \n264834  43461        272          272379  270188        42   \n264835  43365        272          272380  270189        74   \n\n                                       PROD_NAME  PROD_QTY  TOT_SALES  \n0         Natural Chip        Compny SeaSalt175g         2        6.0  \n1                       CCs Nacho Cheese    175g         3        6.3  \n2         Smiths Cr
# ...

# %%
trans_data.describe()
# Out:
#                 DATE     STORE_NBR  LYLTY_CARD_NBR        TXN_ID  \
# count  264836.000000  264836.00000    2.648360e+05  2.648360e+05
# mean    43464.036260     135.08011    1.355495e+05  1.351583e+05
# std       105.389282      76.78418    8.057998e+04  7.813303e+04
# min     43282.000000       1.00000    1.000000e+03  1.000000e+00
# 25%     43373.000000      70.00000    7.002100e+04  6.760150e+04
# 50%     43464.000000     130.00000    1.303575e+05  1.351375e+05
# 75%     43555.000000     203.00000    2.030942e+05  2.027012e+05
# max     43646.000000     272.00000    2.373711e+06  2.415841e+06
#
#             PROD_NBR       PROD_QTY      TOT_SALES
# count  264836.000000  264836.000000  264836.000000
# mean       56.583157       1.907309       7.304200
# std        32.826638       0.643654       3.083226
# min         1.000000       1.000000       1.500000
# 25%        28.000000       2.000000       5.400000
# 50%        56.000000       2.000000       7.400000
# ...

# %%
trans_data.dtypes
# Out:
# DATE                int64
# STORE_NBR           int64
# LYLTY_CARD_NBR      int64
# TXN_ID              int64
# PROD_NBR            int64
# PROD_NAME          object
# PROD_QTY            int64
# TOT_SALES         float64
# dtype: object

# %%
#trans_data["DATE"] = pd.to_datetime(trans_data["DATE"])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 trans_data["DATE"] = pd.to_date(trans_data["DATE"])
#
# AttributeError: module 'pandas' has no attribute 'to_date'

# %%
trans_data.dtypes
# Out:
# DATE                int64
# STORE_NBR           int64
# LYLTY_CARD_NBR      int64
# TXN_ID              int64
# PROD_NBR            int64
# PROD_NAME          object
# PROD_QTY            int64
# TOT_SALES         float64
# dtype: object

# %%
trans_data.head(10)
# Out:
#                            DATE  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  \
# 0 1970-01-01 00:00:00.000043390          1            1000       1         5
# 1 1970-01-01 00:00:00.000043599          1            1307     348        66
# 2 1970-01-01 00:00:00.000043605          1            1343     383        61
# 3 1970-01-01 00:00:00.000043329          2            2373     974        69
# 4 1970-01-01 00:00:00.000043330          2            2426    1038       108
# 5 1970-01-01 00:00:00.000043604          4            4074    2982        57
# 6 1970-01-01 00:00:00.000043601          4            4149    3333        16
# 7 1970-01-01 00:00:00.000043601          4            4196    3539        24
# 8 1970-01-01 00:00:00.000043332          5            5026    4525        42
# 9 1970-01-01 00:00:00.000043330          7            7150    6900        52
#
#                                   PROD_NAME  PROD_QTY  TOT_SALES
# ...

# %%
from datetime import datetime

# %%
trans_data["PROD_NAME"]
# Out:
# 0           Natural Chip        Compny SeaSalt175g
# 1                         CCs Nacho Cheese    175g
# 2           Smiths Crinkle Cut  Chips Chicken 170g
# 3           Smiths Chip Thinly  S/Cream&Onion 175g
# 4         Kettle Tortilla ChpsHny&Jlpno Chili 150g
#                             ...
# 264831     Kettle Sweet Chilli And Sour Cream 175g
# 264832               Tostitos Splash Of  Lime 175g
# 264833                    Doritos Mexicana    170g
# 264834     Doritos Corn Chip Mexican Jalapeno 150g
# 264835               Tostitos Splash Of  Lime 175g
# Name: PROD_NAME, Length: 264836, dtype: object

# %%
trans_data[["brands","test2","test3"]] = trans_data["PROD_NAME"].str.split(" ",expand = True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 trans_data[["brands","test2","test3"]] = trans_data["PROD_NAME"].str.split(" ",expand = True)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4299, in DataFrame.__setitem__(self, key, value)
#    4297     self._setitem_frame(key, value)
#    4298 elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 4299     self._setitem_array(key, value)
#    4300 elif isinstance(value, DataFrame):
#    4301     self._set_item_frame_value(key, value)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4341, in DataFrame._setitem_array(self, key, value)
#    4336 else:
#    4337     # Note: unlike self.iloc[:, indexer] = value, this will
#    4338     #  never try to overwrite values inplace
#    4340     if isinstance(value, DataFrame):
# ...

# %% [markdown]
# #CHECK FOR NULL CELLS
# trans_data.isnull().sum()

# %%
trans_data.isnull().sum()

# %% [raw]
# #EXAMINE THE OUTLIERS

# %%
import seaborn as sns

# %%
sns.displot(trans_data.TOT_SALES, kde = True)

# %%
numericdata = trans_data.select_dtypes(["float","int"])
numericdata.head()
# Out:
#     DATE  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  PROD_QTY  TOT_SALES
# 0  43390          1            1000       1         5         2        6.0
# 1  43599          1            1307     348        66         3        6.3
# 2  43605          1            1343     383        61         2        2.9
# 3  43329          2            2373     974        69         5       15.0
# 4  43330          2            2426    1038       108         3       13.8

# %%
x = numericdata[numericdata["TOT_SALES"]<8.000]

# %%
sns.displot(x.TOT_SALES, kde =True)

# %%
sns.boxplot(x.TOT_SALES)
# Out:
# <Axes: ylabel='TOT_SALES'>
